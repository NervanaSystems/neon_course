# %% [markdown]
# # Part 2: Google Streetview Competition
#
# In this section, you will compete to train a network to solve the Google Streetview challenge. The goal is give you a feeling for the type of problems AI developers face. Adjust the learning rate schedule to achieve the lowest possible training cost!
#
# ## The Problem
#
# Google regularly takes street view photos to populate Google Maps. To associate each photographed house with an address, Google built computer vision algorithms to read the house number from the image. Today we will train a network for the first phase of this process, which is to identify where in the image the house number is located.
#
# This dataset is a collection of 73,257 images of house numbers. Each image has been annotated by a human with a box around the digits.
#
# <img src="http://ufldl.stanford.edu/housenumbers/examples_new.png" width=500px>
#
# Your goal is to train a network to, given a new image, accurately predict the bounding box on the house number.
#
# ## Network
#
# We have already built the model as a neural network with a stack of different types of layers. The input is the image, and the output has 4 numbers, for the coordinates of the predicted box.
#
#
# <img src="image.png", width=800px>
#
# ## Challenge
#
# 1. When you run the code below, a dashboard will be created with several sliders to adjust the learning rate over time. When you click the 'Train' button, the model will begin training with your current settings.
#
# 2. When complete, you will recieve the cost of this current training run, as well as the best cost you have achieved so far.
#
# 3. Adjust the sliders to help the model train to the lowest cost possible. Good luck!

# %%
# setup datasets
# %matplotlib inline
from svhn import train_model, train_model_button, Dashboard

learn_inputs = 4 * [3]
dashboard = Dashboard()
# Out:
# Setting up the data...
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2c9f0f10-24ea-438f-b0c8-df9b3aee6324">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="33b969ef-0dbb-4f92-a883-ecec41c7e36d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("33b969ef-0dbb-4f92-a883-ecec41c7e36d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("0b96f2cb-bbf8-45cf-8558-470ece830193", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("33b969ef-0dbb-4f92-a883-ecec41c7e36d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '33b969ef-0dbb-4f92-a883-ecec41c7e36d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1c707d2f-47cd-43db-bc53-022cfba6cdcd":{"roots":{"references":[{"attributes":{"children":[{"id":"5e271f9b-d10c-4f0d-a5c2-4a46361aadd8","type":"WidgetBox"},{"id":"cc270b80-e56c-49e1-9476-e580a93b0686","subtype":"Figure","type":"Plot"},{"id":"1bb85fa4-c9f3-4503-b578-39af1599f871","type":"Row"}]},"id":"dd4af182-fd9c-4640-aa97-38faa4f98022","type":"Column"},{"attributes":{"callback":null,"start":1e-10},"id":"c66a53cc-6729-4abf-b930-715849c58541","type":"Range1d"},{"attributes":{"below":[{"id":"8f584199-1751-4135-9599-8b35b55186bb","type":"LinearAxis"}],"left":[{"id":"ba298d0d-e7aa-461f-9a92-bbe412591ec8","type":"LinearAxis"}],"name":"cost","plot_height":300,"plot_width":300,"renderers":[{"id":"8f584199-1751-4135-9599-8b35b55186bb","type":"LinearAxis"},{"id":"bd7584ce-236e-4d99-8280-d85b6b28b62c","type":"Grid"},{"id":"ba298d0d-e7aa-461f-9a92-bbe412591ec8","type":"LinearAxis"},{"id":"87c6be19-31c7-467c-bb8f-e397f0da68d3","type":"Grid"},{"id":"f95be08c-e7d0-419f-91a5-c7da29c448b2","type":"BoxAnnotation"},{"id":"76b19608-8e83-4f5d-9458-2719a06f0e07","type":"GlyphRenderer"},{"id":"44ece6fa-7017-404c-bffd-19e6eee10860","type":"GlyphRenderer"}],"title":{"id":"3b160f9e-aa83-45fa-a6f7-b37a4494eb29","type":"Title"},"tool_events":{"id":"7bd7fae7-76ee-425a-9f2d-d24b2d59a037","type":"ToolEvents"},"toolbar":{"id":"3fe975b0-ad1d-4950-be74-ea4e004f36d1","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"67b24411-7d63-4b75-b816-ebfe80a422d3","type":"Range1d"},"y_range":{"id":"5633679c-ebc7-4751-9b61-b070a18dd783","type":"DataRange1d"}},"id":"37125150-d49c-4d0b-a8cf-678b58b004f6","subtype":"Figure","type":"Plot"},{"attributes":{"args":{"source":{"id":"2b2e3c21-2a7c-4542-98d7-7321fe437e78","type":"ColumnDataSource"}},"code":"\n                var data = source.data;\n                var f = cb_obj.value\n                x = data['x']\n                y = data['y']\n                y[6] = Math.pow(10.0, -1.0 * (10-f))\n                y[7] = Math.pow(10.0, -1.0 * (10-f))\n                source.trigger('change');\n\n                var command = 'learn_inputs[3] = ' + f;\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(command)\n            "},"id":"d223687f-4b88-475c-bd73-ce310257068c","type":"CustomJS"},{"attributes":{"button_type":"primary","callback":null,"height":50,"icon":null,"label":"Train","sizing_mode":"fixed","width":300},"id":"583c025e-f47b-4dcb-9353-13a55943bc27","type":"Button"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"01d6f7b2-4ed8-4c6b-a412-c23cea6ffdf8","type":"Line"},{"attributes":{"axis_label":"Learning Rate","formatter":{"id":"ef64e159-b9f0-47e3-a1f4-4c0e49242a74","type":"LogTickFormatter"},"plot":{"id":"cc270b80-e56c-49e1-9476-e580a93b0686","subtype":"Figure","type":"Plot"},"ticker":{"id":"65fd9032-c894-408f-877a-d6b66fb6da1f","type":"LogTicker"}},"id":"4de501b6-8b90-47d4-87fa-f479e50f5ec2","type":"LogAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y":[]}},"id":"0f4bb442-a325-487a-96e2-5d65e8fc327e","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"520c6d25-93ee-47f7-8987-5cd1a06ba78c","type":"Slider"}],"height":50,"width":80},"id":"b558d72f-60d0-4b3f-81bf-670abc6c73d2","type":"WidgetBox"},{"attributes":{"below":[{"id":"fe78a177-1e6a-4077-b1c1-107029d10b0f","type":"LinearAxis"}],"left":[{"id":"4de501b6-8b90-47d4-87fa-f479e50f5ec2","type":"LogAxis"}],"plot_height":200,"plot_width":300,"renderers":[{"id":"fe78a177-1e6a-4077-b1c1-107029d10b0f","type":"LinearAxis"},{"id":"b1d8a44e-06e2-447b-aca4-52b5474a061e","type":"Grid"},{"id":"4de501b6-8b90-47d4-87fa-f479e50f5ec2","type":"LogAxis"},{"id":"96e0804d-e3f6-4866-985e-cd0270f0886a","type":"Grid"},{"id":"0e3f894f-3b6c-4908-bd3d-bbcc97cba9ec","type":"BoxAnnotation"},{"id":"d0d41f78-fd39-4c08-9f21-2ac80f9a35bd","type":"GlyphRenderer"}],"title":{"id":"7959826a-a192-40ce-b420-18642d7bd00b","type":"Title"},"tool_events":{"id":"8fdf ...

# %%
dashboard.train(learn_inputs)
# Out:
# Epoch 0   [Train |████████████████████|   52/52   batches, 1889.84 cost, 14.26s] [SumSquared Loss 1745.76, 2.62s]
# Epoch 1   [Train |████████████████████|   52/52   batches, 1314.19 cost, 14.22s] [SumSquared Loss 1260.93, 2.61s]
# Epoch 2   [Train |████████████████████|   52/52   batches, 959.96 cost, 14.23s]  [SumSquared Loss 936.20, 2.60s]
# Epoch 3   [Train |████████████████████|   52/52   batches, 796.74 cost, 14.24s] [SumSquared Loss 761.56, 2.60s]
# This current got run a Cost: [ 761.55993652]
# Your best run so far had Cost: [ 761.55993652]
# Note: lower is better.
